# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Define the data points (A, B, C, D, E, F)
data = np.array([
    [2, 3],  # Point A
    [3, 3],  # Point B
    [6, 8],  # Point C
    [8, 8],  # Point D
    [7, 5],  # Point E
    [9, 5]   # Point F
])
 
# Perform K-means clustering with K=2
kmeans = KMeans(n_clusters=2, random_state=0).fit(data)
 
# Get the cluster centers (centroids) and labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
 
# Print the final centroids and cluster assignments
print("Final Centroids (Cluster Centers):")
print(centroids)
print("\nCluster Assignments:")
for i, label in enumerate(labels):
    print(f"Point {chr(65+i)}: Cluster {label+1}")
 
# Plot the data points and the centroids
plt.scatter(data[:, 0], data[:, 1],c=labels, cmap='viridis', marker='o', label='Data Points')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=100, label='Centroids')
 
# Annotate points
for i, point in enumerate(data):
    plt.text(point[0]+0.1, point[1]+0.1, f'{chr(65+i)}', fontsize=12)

plt.title('K-means Clustering Example')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Final Centroids (Cluster Centers):
# [[7.5 6.5]
#  [2.5 3. ]]
#
# Cluster Assignments:
# Point A: Cluster 2
# Point B: Cluster 2
# Point C: Cluster 1
# Point D: Cluster 1
# Point E: Cluster 1
# Point F: Cluster 1

# %%
import pandas as pd

df = pd.read_csv("./kmeans_dataset_with_outliers.csv").iloc[:,:-1]

# %%
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0).fit(df)
    wcss.append(kmeans.inertia_)  # inertia_ gives the WCSS

plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.title('Elbow Method')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Within-Cluster-Sum of Squared Errors (WCSS)')
plt.show()

# %%
 
# Perform K-means clustering with K=8 from elbow method
kmeans = KMeans(n_clusters=8, random_state=0).fit(df)
 
# Get the cluster centers (centroids) and labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
 
# Print the final centroids and cluster assignments
print("Final Centroids (Cluster Centers):")
print(centroids)
print("\nCluster Assignments:")
for i, label in enumerate(labels):
    print(f"Point {chr(65+i)}: Cluster {label+1}")
# Out:
# Final Centroids (Cluster Centers):
# [[  1.83339357   3.02193672]
#  [-37.23162248  34.93395785]
#  [ 46.24031459  43.82372642]
#  [-33.85862183 -26.54578253]
#  [  6.61613535   7.18494117]
#  [  5.60077105  44.70614033]
#  [ 46.5737542   -5.10157882]
#  [  8.36561119 -42.2265363 ]]
#
# Cluster Assignments:
# Point A: Cluster 1
# Point B: Cluster 1
# Point C: Cluster 1
# Point D: Cluster 1
# Point E: Cluster 1
# Point F: Cluster 1
# Point G: Cluster 1
# Point H: Cluster 1
# Point I: Cluster 1
# Point J: Cluster 1
# Point K: Cluster 1
# Point L: Cluster 1
# Point M: Cluster 1
# Point N: Cluster 1
# Point O: Cluster 1
# Point P: Cluster 1
# Point Q: Cluster 1
# Point R: Cluster 1
# Point S: Cluster 1
# Point T: Cluster 1
# Point U: Cluster 1
# Point V: Cluster 1
# Point W: Cluster 1
# Point X: Cluster 1
# Point Y: Cluster 1
# Point Z: Cluster 1
# Point [: Cluster 1
# Point \: Cluster 1
# Point ]: Cluster 1
# Point ^: Cluster 1
# Point _: Cluster 1
# Point `: Cluster 1
# Point a: Cluster 1
# Point b: Cluster 1
# Point c: Cluster 1
# Point d: Cluster 1
# Point e: Cluster 1
# Point f: Cluster 1
# Point g: Cluster 1
# Point h: Cluster 1
# Point i: Cluster 1
# Point j: Cluster 1
# Point k: Cluster 1
# Point l: Cluster 1
# Point m: Cluster 1
# Point n: Cluster 1
# Point o: Cluster 1
# Point p: Cluster 1
# Point q: Cluster 1
# Point r: Cluster 1
# Point s: Cluster 1
# Point t: Cluster 1
# Point u: Cluster 1
# Point v: Cluster 1
# Point w: Cluster 1
# Point x: Cluster 1
# Point y: Cluster 1
# Point z: Cluster 1
# Point {: Cluster 1
# Point |: Cluster 1
# Point }: Cluster 1
# Point ~: Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point : Cluster 1
# Point  : Cluster 1
# Point ¡: Cluster 1
# Point ¢: Cluster 1
# Point £: Cluster 1
# Point ¤: Cluster 1
# Point ¥: Cluster 1
# Point ¦: Cluster 1
# Point §: Cluster 1
# Point ¨: Cluster 1
# Point ©: Cluster 1
# Point ª: Cluster 1
# Point «: Cluster 1
# Point ¬: Cluster 1
# Point ­: Cluster 1
# Point ®: Cluster 1
# Point ¯: Cluster 1
# Point °: Cluster 1
# Point ±: Cluster 1
# Point ²: Cluster 1
# Point ³: Cluster 1
# Point ´: Cluster 1
# Point µ: Cluster 1
# Point ¶: Cluster 1
# Point ·: Cluster 1
# Point ¸: Cluster 1
# Point ¹: Cluster 5
# Point º: Cluster 5
# Point »: Cluster 5
# Point ¼: Cluster 5
# Point ½: Cluster 5
# Point ¾: Cluster 5
# Point ¿: Cluster 5
# Point À: Cluster 5
# Point Á: Cluster 5
# Point Â: Cluster 5
# Point Ã: Cluster 5
# Point Ä: Cluster 5
# Point Å: Cluster 5
# Point Æ: Cluster 5
# Point Ç: Cluster 5
# Point È: Cluster 5
# Point É: Cluster 5
# Point Ê: Cluster 5
# Point Ë: Cluster 5
# Point Ì: Cluster 5
# Point Í: Cluster 5
# Point Î: Cluster 5
# Point Ï: Cluster 5
# Point Ð: Cluster 5
# Point Ñ: Cluster 5
# Point Ò: Cluster 5
# Point Ó: Cluster 5
# Point Ô: Cluster 5
# Point Õ: Cluster 5
# Point Ö: Cluster 5
# Point ×: Cluster 5
# Point Ø: Cluster 5
# Point Ù: Cluster 5
# Point Ú: Cluster 5
# Point Û: Cluster 5
# Point Ü: Cluster 5
# Point Ý: Cluster 5
# Point Þ: Cluster 5
# Point ß: Cluster 5
# Point à: Cluster 5
# Point á: Cluster 5
# Point â: Cluster 5
# Point ã: Cluster 5
# Point ä: Cluster 5
# Point å: Cluster 5
# Point æ: Cluster 5
# Point ç: Cluster 5
# Point è: Cluster 5
# Point é: Cluster 5
# Point ê: Cluster 5
# Point ë: Cluster 5
# Point ì: Cluster 5
# Point í: Cluster 5
# Point î: Cluster 5
# Point ï: Cluster 5
# Point ð: Cluster 5
# Point ñ: Cluster 5
# Point ò: Cluster 5
# Point ó: Cluster 5
# Point ô: Cluster 5
# Point õ: Cluster 5
# Point ö: Cluster 7
# Point ÷: Cluster 2
# Point ø: Cluster 2
# Point ù: Cluster 2
# Point ú: Cluster 2
# Point û: Cluster 6
# Point ü: Cluster 2
# Point ý: Cluster 7
# Point þ: Cluster 5
# Point ÿ: Cluster 1
# Point Ā: Cluster 6
# Point ā: Cluster 4
# Point Ă: Cluster 3
# Point ă: Cluster 1
# Point Ą: Cluster 4
# Point ą: Cluster 1
# Point Ć: Cluster 8
# Point ć: Cluster 3
# Point Ĉ: Cluster 5

# %%
# Plot the data points and the centroids
plt.scatter(df["X"], df["Y"], c = labels, cmap='viridis', marker='o', label='df Points')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='x', s=100, label='Centroids')
 

plt.title('K-means Clustering Example')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)
plt.show()
